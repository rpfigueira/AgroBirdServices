# %% [markdown]
# # 04 - Create list of pests for the crops in the selected area
#
# ### Description
# The goal of this notebook is to:
# - create a dataset with the list of possible pests that affect the crops of the selected area
# - provide an interface for the selection of the pests (not implemented yet)
#
#
# ### Inputs
#
# - List of crops (EPPO codes) in the area of interest, created by step 02
#
# ### External resources
#
# - External API service: EPPO API service, to provide data on which pests affect which crop
#
# ### Outputs
#
# - dataset with pests for each crop, including pest taxonomy: eppo_crop_pest_data.csv
# - list with common names of the pests: pest_common.csv

# %%
# import modules
import pandas as pd
import requests
# %matplotlib inline

# %% [markdown]
# ## 1. Read list of crops
#
# In step 02 of the workflow, we created a list of the crops occurring in the area of interest, from the crop classification done by CROPLandCOS service. We added the EPPO code for each crop to that list.

# %%
# read the list of crops
in_file = '../process_data/crop_data.csv'
df = pd.read_csv(in_file)

# remove nan
df = df[df['EPPO_code'].notna()]
crops = df[['EPPO_code']]

# resolve multivalues
crops = crops['EPPO_code'].str.split(",")
crops = crops.explode('EPPO_code')
crops = crops.unique()
crops
#crops = ['ZEAMX', 'MEDSA']
# Out:
# array(['ZEAMX', '1GOSG', 'ORYSA', 'SORVU', 'HELAN', 'ZEAMS', 'ZEAME',
#        '1MENG', 'HORVX', 'TRZDU', 'TRZAX', 'SECCE', 'AVESA', 'CAUTI',
#        'BRSJU', 'MEDSA', 'BEAVX', 'SOLTU', 'IPOBA', 'CITLA', 'ALLCE',
#        'CUMSA', 'CIEAR', 'PIBSX', 'LYPES', 'PRNSS', 'PRNPS', 'MABSS',
#        'VITSS', 'CIDSS', 'CYAIL', 'PRDU', 'IUGSS', 'PYUCO', 'NNNWW',
#        'PIAVE', 'TTLRI', 'DAUCA', 'ALLSA', 'CUMMC', 'PRNDO', 'OLVEU',
#        'CIDSI', 'CUMI', 'BRSOK', 'PEBAM', 'CPSAN', 'PUNGR', 'PRNPN',
#        'BRSOA', 'FRAAN', 'CUUPE', 'VICSA', 'LACSA', 'VACSS'], dtype=object)

# %% [markdown]
# ## 2. Get data from EPPO API service
#
# We will use the [EPPO Global Database](https://gd.eppo.int/) to identify which pests are known for each crop. To access to the EPPO database API, it is necessary to obtain a token. You can obtain one after registering at https://data.eppo.int/.

# %%
# define EPP API service parameters
base_url = 'https://data.eppo.int/api/rest/1.0/taxon/'
service = '/pests'
token = 'b2cdcf68881f7ac1bbfb4d0acf00b945'

# %% [markdown]
# Insert your EDDP database token here:

# %%
token = input('Please enter the EPPO API token:')
print(token)
# Out:
# Please enter the EPPO API token:b2cdcf68881f7ac1bbfb4d0acf00b945
# b2cdcf68881f7ac1bbfb4d0acf00b945

# %% [markdown]
# The next step will gather all pests that exist in the EPPO database that are identified to have a crop as 'major host' or 'host'.

# %%
# %%time
# Identifies pests for whihc the crop is identified as 'major host' or 'host'.

df = pd.DataFrame()

concat_dfs = []

for crop in crops:
    # print(crop)
    url = base_url+crop+service+'?authtoken='+token
    # print(url)
    response = requests.get(url)
    data = response.json()
    # print(data)
    if (data != None):
        if 'Major host' in data:
            df = pd.DataFrame.from_dict(data['Major host'])
        if 'Host' in data:
            df = pd.concat([df, pd.DataFrame.from_dict(data['Host'])], axis = 0, ignore_index = True, sort = True)
        df['crop_eppocode'] = crop
        concat_dfs.append(df)

df_hosts = pd.concat(concat_dfs)
df_hosts.head()
# Out:
# CPU times: user 4.19 s, sys: 43.7 ms, total: 4.23 s
# Wall time: 18.3 s
#   eppocode                            fullname  idclass  labelclass  \
# 0   MIRMV0  Alphanucleorhabdovirus zeairanense        1  Major host
# 1   APLOBE              Aphelenchoides besseyi        1  Major host
# 2   COCHCA                   Bipolaris zeicola        1  Major host
# 3   BUSSFU                      Busseola fusca        1  Major host
# 4   PHYPSO     'Candidatus Phytoplasma solani'        1  Major host
#
#   crop_eppocode
# 0         ZEAMX
# 1         ZEAMX
# 2         ZEAMX
# 3         ZEAMX
# 4         ZEAMX

# %%
# creates and saves a dataframe with crop pests by removing duplicates
pest_codes = df_hosts[['eppocode', 'crop_eppocode']].drop_duplicates()
pest_codes.to_csv('../process_data/pest_codes.csv')

# %%
# create a unique list pest eppocodes to get its taxonomy
codes = pest_codes['eppocode'].unique()
len(codes)
# Out:
# 920

# %% [markdown]
# A total of 920 pests where identified for the crops in the area of interest.

# %%
# %%time
# Get taxonomy for each pest. This can take 4 minutes to run for a list of 2000 pest codes
group_n = 1
service = '/taxonomy'
tax = pd.DataFrame()


concatenated_dfs = []

for code in codes:
    url = base_url+code+service+'?authtoken='+token
    # print(url)
    response = requests.get(url)
    data = response.json()
    if data != None:
        tax = pd.DataFrame.from_dict(data)
        tax['kingdom'] = tax['prefname'][0]
        tax['group'] = group_n
        tax['pest_eppocode'] = code
        concatenated_dfs.append(tax)
        group_n += 1

df_tax = pd.concat(concatenated_dfs)

# retain only pests caused by animals
df_tax = df_tax[df_tax['kingdom'] == 'Animalia']
# Out:
# CPU times: user 1min 8s, sys: 967 ms, total: 1min 9s
# Wall time: 5min

# %%
# if you have previously saved the output of the previous step, you can uncomment bellow to read a file
# and skip previous steps:

# pest_codes = pd.read_csv('../process_data/clip/crop_data.csv')
# df_tax = pd.read_csv('../process_data/pest_taxonomy.csv')

# %%
# save pest taxonomy
df_tax.to_csv('../process_data/pest_taxonomy.csv')

# %% [markdown]
# ## 3. Create table with main taxonomic levels for each pest
#
# This step will prepare a table with higher taxonomic levels for each pest. This is necessary to determine if birds potentially use these insects as food. Many times, insects as preys of birds are not reported at species level, but at a higher taxonomic rank.

# %%
# create a table with kingdom, order (level 5 for Insecta) and 

# group the pests
pest_tax_group = df_tax.groupby(['group'])

# determine the number of levels for each pest
df4 = pest_tax_group.size()
df5 = df4.to_frame()
df5.rename(columns={0:'group_size'}, inplace=True)

# create a column with the number of the group
df5.reset_index(inplace=True)

# merge the group with the taxonomy
df_tax1 = pd.merge(df_tax, df5, left_on=['group'], right_on=['group'])

# make a pivot for taxonomy, when levels are equal to 7
df_tax2 = df_tax1[df_tax1['group_size'] == 7]
df_tax3 = df_tax2.pivot(index='group', columns='level', values=['eppocode', 'prefname'])

# rename columns
df_tax3.rename(columns={1:'kingdom', 2:'phylum', 3:'class', 4:'order', 5:'family', 6:'genus', 7:'species'}, 
               inplace=True)
df_tax3.columns = [' '.join(col).strip() for col in df_tax3.columns.values]

# add columns for missing taxon ranks
df_tax3.insert(loc = 2, column = 'eppocode subphylum', value = '')
df_tax3.insert(loc = 10, column = 'prefname subphylum', value = '')
df_tax3.insert(loc = 5, column = 'eppocode suborder', value = '')
df_tax3.insert(loc = 14, column = 'prefname suborder', value = '')

# make a pivot for taxonomy, when levels are equal to 8
df_tax2 = df_tax1[df_tax1['group_size'] == 8]
df_tax4 = df_tax2.pivot(index='group', columns='level', values=['eppocode', 'prefname'])
df_tax4.rename(columns={1:'kingdom', 2:'phylum', 3:'subphylum', 4:'class', 5:'order', 6:'family', 
                        7:'genus', 8:'species'}, 
               inplace=True)
df_tax4.columns = [' '.join(col).strip() for col in df_tax4.columns.values]
df_tax4.insert(loc = 5, column = 'eppocode suborder', value = '')
df_tax4.insert(loc = 14, column = 'prefname suborder', value = '')

# make a pivot for taxonomy, when levels are equal to 9
df_tax2 = df_tax1[df_tax1['group_size'] == 9]
df_tax5 = df_tax2.pivot(index='group', columns='level', values=['eppocode', 'prefname'])
df_tax5.rename(columns={1:'kingdom', 2:'phylum', 3:'subphylum', 4:'class', 5:'order', 6:'suborder', 
                        7:'family', 8:'genus', 9:'species'}, 
               inplace=True)
df_tax5.columns = [' '.join(col).strip() for col in df_tax5.columns.values]
df_tax5.columns

frames = [df_tax3, df_tax4, df_tax5]
tax_table = pd.concat(frames)

# save to csv
tax_table.to_csv('../process_data/tax_table.csv')

tax_table
# Out:
#       eppocode kingdom eppocode phylum eppocode subphylum eppocode class  \
# group
# 2               1ANIMK          1NEMAP                            1CHROC
# 22              1ANIMK          1NEMAP                            1CHROC
# 40              1ANIMK          1NEMAP                            1CHROC
# 77              1ANIMK          1NEMAP                            1CHROC
# 78              1ANIMK          1NEMAP                            1CHROC
# ...                ...             ...                ...            ...
# 893             1ANIMK          1ARTHP             1HEXAQ         1INSEC
# 895             1ANIMK          1ARTHP             1HEXAQ         1INSEC
# 896             1ANIMK          1ARTHP             1HEXAQ         1INSEC
# 897             1ANIMK          1ARTHP             1HEXAQ         1INSEC
# 920             1ANIMK          1ARTHP             1HEXAQ         1INSEC
#
#       eppocode order eppocode suborder eppocode family eppocode genus  \
# group
# 2             1RHABO                            1APLOF         1APLOG
# 22            1RHABO                            1HETEF         1HETDG
# 40            1RHABO                            1HETEF         1PUNCG
# 77            1RHABO                            1ANGUF         1DITYG
# 78            1RHABO                            1ANGUF         1DITYG
# ...              ...               ...             ...            ...
# 893           1HEMIO            1STERR          1DIASF         1AONDG
# 895           1HEMIO            1STERR          1PSEUF         1RIPLG
# 896           1COLEO            1CURCF          1CURCS         1ANTHG
# 897           1COLEO            1CURCF          1CURCS         1ANTHG
# 920           1HEMIO            1HETER          1TINGF         1STEPG
#
#       eppocode species prefname kingdom prefname phylum prefname subphylum  \
# group
# 2               APLOBE         Animalia        Nematoda
# 22              HETDZE         Animalia        Nematoda
# 40              PUNCCH         Animalia        Nematoda
# 77              DITYDE         Animalia        Nematoda
# 78              DITYDI         Animalia        Nematoda
# ...                ...              ...             ...                ...
# 893             AONDOR         Animalia      Arthropoda           Hexapoda
# 895             RHIOHI         Animalia      Arthropoda           Hexapoda
# 896             ANTHBI         Animalia      Arthropoda           Hexapoda
# 897             ANTHSI         Animalia      Arthropoda           Hexapoda
# 920             STEPTA         Animalia      Arthropoda           Hexapoda
#
#       prefname class prefname order prefname suborder   prefname family  \
# group
# 2        Chromadorea     Rhabditida                    Aphelenchoididae
# 22       Chromadorea     Rhabditida                       Heteroderidae
# 40       Chromadorea     Rhabditida                       Heteroderidae
# 77       Chromadorea     Rhabditida                          Anguinidae
# 78       Chromadorea     Rhabditida                          Anguinidae
# ...              ...            ...               ...               ...
# 893          Insecta      Hemiptera    Sternorrhyncha       Diaspididae
# 895          Insecta      Hemiptera    Sternorrhyncha    Pseudococcidae
# 896          Insecta     Coleoptera     Curculionidae     Curculioninae
# 897          Insecta     Coleoptera     Curculionidae     Curculioninae
# 920          Insecta      Hemiptera       Heteroptera          Tingidae
#
#        prefname genus        prefname species
# group
# 2      Aphelenchoides  Aphelenchoides besseyi
# 22         Heterodera         Heterodera zeae
# 40         Punctodera  Punctodera chalcoensis
# 77        Ditylenchus  Ditylenchus destructor
# 78        Ditylenchus     Ditylenchus dipsaci
# ...               ...                     ...
# 893        Aonidiella   Aonidiella orientalis
# 895       Ripersiella     Ripersiella hibisci
# 896        Anthonomus   Anthonomus bisignifer
# 897        Anthonomus     Anthonomus signatus
# 920       Stephanitis     Stephanitis takeyai
#
# [528 rows x 18 columns]

# %%
# merge taxonomy with crop pests and remove duplicates
result = pd.merge(tax_table, pest_codes, left_on=['eppocode species'], right_on=['eppocode'], how='left')
result = result.drop_duplicates()

# %%
# save to csv
result.to_csv('../process_data/eppo_crop_pest_data.csv')

# %% [markdown]
# ## 4. Create a list of pests to present to the farmer
#
# Get pest common names from EPPO to be present to the farmer, so that he can confirm that the pest in present in the region.

# %%
pests = result['eppocode species'].unique()

# %%
# %%time
# Get common name for each pest. This can take 4 minutes to run for a list of 2000 pest codes

service = '/names'
df = pd.DataFrame()


concatenated_dfs = []

for pest in pests:
    url = base_url+pest+service+'?authtoken='+token
    # print(url)
    response = requests.get(url)
    data = response.json()
    if data != None:
        species = data[0]['fullname']
        print(f'Species:. {species}')
        if len(data) > 1:
            common = data[1]['fullname']
        else:
            common = ""
        print(f'Common: {common}')
        values = {'pest_eppocode': [pest], 'scientific_name': [species], 
                   'common_name': [common]}
        df = pd.DataFrame.from_dict(values)
        concatenated_dfs.append(df)

df_common = pd.concat(concatenated_dfs)
df_common.head()
# Out:
# Species:. Aphelenchoides besseyi
# Common: white-tip nematode
# Species:. Heterodera zeae
# Common: corn cyst nematode
# Species:. Punctodera chalcoensis
# Common: Mexican corn cyst nematode
# Species:. Ditylenchus destructor
# Common: kartoffelradnematod
# Species:. Ditylenchus dipsaci
# Common: stængelnematod
# Species:. Heterodera elachista
# Common: Japanese cyst nematode
# Species:. Meloidogyne chitwoodi
# Common: Columbia root-knot nematode
# Species:. Meloidogyne ethiopica
# Common: root-knot nematode
# Species:. Meloidogyne graminicola
# Common: Rice root‐knot nematode
# Species:. Meloidogyne luci
# Common: nemátode das galhas do arroz
# Species:. Trichodorus viruliferus
# Common: stubby root nematode
# Species:. Tylenchorhynchus claytoni
# Common: stunt nematode
# Species:. Rotylenchulus reniformis
# Common: reniform nematode
# Species:. Heterodera oryzae
# Common: Reiszystenälchen
# Species:. Hirschmanniella imamuri
# Common:
# Species:. Hirschmanniella oryzae
# Common: Reiswurzelälchen
# Species:. Hirschmanniella spinicaudata
# Common: root lesion nematode
# Species:. Pomacea canaliculata
# Common: channeled apple snail
# Species:. Pomacea maculata
# Common: island apple snail
# Species:. Ditylenchus angustus
# Common: akhet-pet
# Species:. Meloidogyne exigua
# Common: coffee root nematode
# Species:. Meloidogyne naasi
# Common: barley root-knot nematode
# Species:. Heterodera hordecalis
# Common: Bidera hordecalis
# Species:. Meloidogyne fallax
# Common: false Columbia root-knot nematode
# Species:. Anguina tritici
# Common: hvedeal
# Species:. Heterodera latipons
# Common: cereal cyst nematode
# Species:. Rotylenchus buxophilus
# Common: spiral nematode
# Species:. Aphelenchoides fragariae
# Common: anguillule du fraisier et des fougères
# Species:. Heterodera schachtii
# Common: roeål
# Species:. Nacobbus aberrans sensu lato
# Common: false root-knot nematode
# Species:. Otala lactea
# Common: milchige Schnecke
# Species:. Heterodera glycines
# Common: Sojabohnenzystenälchen
# Species:. Meloidogyne enterolobii
# Common: guava root-knot nematode
# Species:. Globodera pallida
# Common: cremefarbenes Kartoffelzystenälchen
# Species:. Globodera rostochiensis
# Common: kartoffelal
# Species:. Meloidogyne minor
# Common:
# Species:. Lissachatina fulica
# Common: afrikanische Riesenschnecke
# Species:. Pratylenchus coffeae
# Common: root lesion nematode
# Species:. Scutellonema bradys
# Common: lesion nematode
# Species:. Longidorus diadecturus
# Common:
# Species:. Meloidogyne mali
# Common: apple root-knot nematode
# Species:. Radopholus similis citrus race
# Common: citrus burrowing nematode
# Species:. Theba pisana
# Common: Mittelmeersandschnecke
# Species:. Tylenchulus semipenetrans
# Common: Orangenwurzelnematode
# Species:. Radopholus similis
# Common: burrowing nematode
# Species:. Aphelenchoides ritzemabosi
# Common: bladal
# Species:. Busseola fusca
# Common: Maisstengelbohrer
# Species:. Chilo agamemnon
# Common: gestreifter Maisbohrer
# Species:. Chilo partellus
# Common: blaßroter Stengelbohrer
# Species:. Delia platura
# Common: bønneflue
# Species:. Diabrotica barberi
# Common: northern corn rootworm
# Species:. Diabrotica speciosa
# Common: vaquita de San Antonio
# Species:. Diabrotica undecimpunctata howardi
# Common: southern corn rootworm
# Species:. Diabrotica undecimpunctata undecimpunctata
# Common: corn budworm
# Species:. Diabrotica virgifera virgifera
# Common: westliche Maiswurzelbohrer
# Species:. Diabrotica virgifera zeae
# Common: Mexican corn rootworm
# Species:. Eoreuma loftini
# Common: Mexican rice borer
# Species:. Eriophyes zealus
# Common: corn eriophyid mite
# Species:. Exomala orientalis
# Common: oriental beetle
# Species:. Helicoverpa zea
# Common: amerikansk bomuldsugle
# Species:. Heteronychus arator
# Common: schwarzer Maiskäfer
# Species:. Melanotus communis
# Common: common wireworm
# Species:. Orgyia leucostigma
# Common: white-marked tussock moth
# Species:. Ostrinia nubilalis
# Common: majsborer
# Species:. Popillia japonica
# Common: japanbille
# Species:. Prostephanus truncatus
# Common: großer Kornbohrer
# Species:. Sesamia calamistis
# Common: afrikanischer Stengelbohrer
# Species:. Sesamia cretica
# Common: Hirsestengelbohrer
# Species:. Sesamia uniformis
# Common: maize shoot borer
# Species:. Spodoptera frugiperda
# Common: Heerwurm
# Species:. Spodoptera littoralis
# Common: afrikansk bomuldsugle
# Species:. Spodoptera litura
# Common: Baumwollblattraupe
# Species:. Thaumatotibia leucotreta
# Common: citrus codling moth
# Species:. Adoretus sinicus
# Common: Chinese rose beetle
# Species:. Agrotis segetum
# Common: agerugle
# Species:. Atherigona oryzae
# Common: rice shoot fly
# Species:. Atherigona reversura
# Common: bermudagrass stem maggot
# Species:. Aulacophora hilaris
# Common: pumpkin flea beetle
# Species:. Ceratothripoides brunneus
# Common: tomato thrips
# Species:. Chilo infuscatellus
# Common: gelber Zuckerrohrbohrer
# Species:. Chrysodeixis eriosoma
# Common: cabbage semi-looper
# Species:. Conoderus rufangulus
# Common: Conoderus pallipes
# Species:. Cryptoblabes gnidiella
# Common: rind-boring orange moth
# Species:. Cylas puncticollis
# Common: schwarzer Batatenkäfer
# Species:. Delia arambourgi
# Common: barley fly
# Species:. Diatraea saccharalis
# Common: amerikanischer Zuckerrohrbohrer
# Species:. Dichocrocis punctiferalis
# Common: Zünsler
# Species:. Earias insulana
# Common: ägyptischer Baumwollkapselwurm
# Species:. Elasmopalpus lignosellus
# Common: kleiner Maisstengelbohrer
# Species:. Eldana saccharina
# Common: Zuckerrohrstengelbohrer
# Species:. Helicoverpa armigera
# Common: amerikansk bomuldsugle
# Species:. Metamasius hemipterus
# Common: West Indian cane weevil
# Species:. Mussidia nigrivenella
# Common: yam bean borer
# Species:. Mythimna separata
# Common: asiatische Reiseule
# Species:. Nacoleia octasema
# Common: Bananenschorfmotte
# Species:. Opogona sacchari
# Common: Bananenmotte
# Species:. Pheletes californicus
# Common: sugarbeet wireworm
# Species:. Platynota stultana
# Common: omnivorous leaf roller
# Species:. Rhabdoscelus obscurus
# Common: cane weevil borer
# Species:. Spodoptera eridania
# Common: southern armyworm
# Species:. Spodoptera mauritia
# Common: Reissateule
# Species:. Spodoptera ornithogalli
# Common: yellow-striped armyworm
# Species:. Spodoptera praefica
# Common: western yellow-striped armyworm
# Species:. Thrips hawaiiensis
# Common: Hawaiian flower thrips
# Species:. Thrips palmi
# Common: palm thrips
# Species:. Thrips parvispinus
# Common: tobacco thrips
# Species:. Trogoderma granarium
# Common: Khapra-Käfer
# Species:. Anomis flava
# Common: cotton looper
# Species:. Apion soleatum
# Common: cotton stem weevil
# Species:. Ceratitis capitata
# Common: middelhavsfrugtflue
# Species:. Crocidosema plebejana
# Common: cotton tip borer
# Species:. Diparopsis castanea
# Common: südostafrikanischer Baumwollkapselwurm
# Species:. Earias biplaga
# Common: spiny bollworm
# Species:. Earias vittella
# Common: northern rough bollworm
# Species:. Eutetranychus orientalis
# Common: orientalische Spinnmilbe
# Species:. Pectinophora gossypiella
# Common: roter Baumwollkapselwurm
# Species:. Pectinophora scutigera
# Common: pink-spotted bollworm
# Species:. Platyedra subcinerea
# Common: cotton stem moth
# Species:. Scirtothrips aurantii
# Common: Zitrusblasenfuß
# Species:. Tetranychus mexicanus
# Common: ácaro mexicano
# Species:. Tetranychus pacificus
# Common: Pacific mite
# Species:. Zeuzera coffeae
# Common: roter Kaffeebohrer
# Species:. Agromyza oryzae
# Common: Reisminierfliege
# Species:. Chilo auricilius
# Common: gold-fringed moth
# Species:. Chilo suppressalis
# Common: gestreifter Reisbohrer
# Species:. Dicladispa armigera
# Common: asiatisches Reisigelkäferchen
# Species:. Gonocephalum acutangulum
# Common: Gonocephalum aequatoriale
# Species:. Gonocephalum depressum
# Common: Dasus depressum
# Species:. Gonocephalum simplex
# Common: koffiepit
# Species:. Lissorhoptrus oryzophilus
# Common: amerikanischer Reisrüsselkäfer
# Species:. Orseolia oryzae
# Common: Reisgallmücke
# Species:. Scirpophaga incertulas
# Common: gelber Reisbohrer
# Species:. Spodoptera exempta
# Common: Heerwurm
# Species:. Stenchaetothrips biformis
# Common: Reisblasenfuß
# Species:. Chilo polychrysus
# Common: schwarzköpfiger Reisstengelbohrer
# Species:. Diopsis thoracica
# Common: Reisstielaugenfliege
# Species:. Lema oryzae
# Common: Reishähnchen
# Species:. Microcephalothrips abdominalis
# Common: composite thrips
# Species:. Parnara guttata
# Common: Reisdickkopffalter
# Species:. Scirpophaga innotata
# Common: weißer Reisstengelbohrer
# Species:. Scirpophaga nivella
# Common: Spitzenbohrer
# Species:. Sesamia inferens
# Common: violetter Stengelbohrer
# Species:. Thrips setosus
# Common: tobacco thrips
# Species:. Trichispa sericea
# Common: afrikanisches Reisigelkäferchen
# Species:. Stenodiplosis sorghicola
# Common: amerikanische Hirsegallmücke
# Species:. Chloridea virescens
# Common: amerikanische Tabakknospeneule
# Species:. Liriomyza sativae
# Common: cabbage leaf miner
# Species:. Nemorimyza maculosa
# Common: amerikanischer Blattminierer
# Species:. Strauzia longipennis
# Common: peacock fly
# Species:. Brevipalpus yothersi
# Common: Brevipalpus amicus
# Species:. Choristoneura rosaceana
# Common: oblique-banded leaf roller
# Species:. Epitrix tuberis
# Common: tuber flea beetle
# Species:. Frankliniella occidentalis
# Common: Blütenthrips
# Species:. Liriomyza trifolii
# Common: Floridaminierfliege
# Species:. Delia coarctata
# Common: brakflue
# Species:. Contarinia tritici
# Common: alm hvedemyg
# Species:. Mayetiola destructor
# Common: hessisk flue
# Species:. Sitodiplosis mosellana
# Common: hvedegalmyg
# Species:. Epilachna similis similis
# Common: cereal ladybird
# Species:. Haplothrips tritici
# Common: europäischer Weizenblasenfuß
# Species:. Oulema melanopus
# Common: kornbladbille
# Species:. Thrips angusticeps
# Common: kåltrips
# Species:. Athalia rosae
# Common: kålbladhveps
# Species:. Contarinia nasturtii
# Common: krusesygegalmyg
# Species:. Delia floralis
# Common: stor kalflue
# Species:. Delia florilega
# Common: lupinflue
# Species:. Helophorus rufipes
# Common: turnip mud beetle
# Species:. Liriomyza bryoniae
# Common: Kartoffelminierfliege
# Species:. Liriomyza huidobrensis
# Common: pea leaf miner
# Species:. Mamestra brassicae
# Common: kålugle
# Species:. Nephrotoma appendiculata
# Common: gefleckte Schnake
# Species:. Omophlus lepturoides
# Common:
# Species:. Phaedon brassicae
# Common: small cabbage beetle
# Species:. Phyllotreta atra
# Common: blanksort jordloppe
# Species:. Phyllotreta cruciferae
# Common: gewöhnlicher Erdfloh
# Species:. Phytomyza rufipes
# Common: kålminerflue
# Species:. Pieris brassicae
# Common: stor kålsommerfugl
# Species:. Psylliodes chrysocephala
# Common: rapsjordloppe
# Species:. Tatochila autodice
# Common: white cabbage butterfly
# Species:. Gonioctena fornicata
# Common: roter Luzerneblattkäfer
# Species:. Epichoristodes acerbella
# Common: sydafrikansk nellikevikler
# Species:. Epiphyas postvittana
# Common: apple leaf roller
# Species:. Lobesia botrana
# Common: Heuwurm
# Species:. Prodiplosis longifila
# Common: citrus gall midge
# Species:. Scirtothrips citri
# Common: Kakaothrips
# Species:. Thrips imaginis
# Common: plague thrips
# Species:. Tuta absoluta
# Common: tomatmøl
# Species:. Autographa gamma
# Common: gammaugle
# Species:. Scrobipalpa ocellatella
# Common: Rübenmotte
# Species:. Leucinodes orbonalis
# Common: Auberginenfruchtbohrer
# Species:. Phthorimaea operculella
# Common: kartoffelmol
# Species:. Tetranychus evansi
# Common: red spider mite
# Species:. Epilachna vigintioctomaculata
# Common: large 28-spotted lady beetle
# Species:. Epitrix cucumeris
# Common: amerikanischer Kartoffelerdfloh
# Species:. Epitrix papa
# Common: epitrix da batateira
# Species:. Epitrix similaris
# Common: amerikanische Kartoffelerdflöhe
# Species:. Epitrix subcrinita
# Common: western potato flea beetle
# Species:. Leptinotarsa decemlineata
# Common: coloradobille
# Species:. Tecia solanivora
# Common: Guatemala-Kartoffelmotte
# Species:. Aculops lycopersici
# Common: Tomatenmilbe
# Species:. Agrius convolvuli
# Common: Windenschwärmer
# Species:. Cacoecimorpha pronubana
# Common: nellikevikler
# Species:. Dacus bivittatus
# Common: pumpkin fruit fly
# Species:. Epitrix hirtipennis
# Common: Tabakerdfloh
# Species:. Keiferia lycopersicella
# Common: tomato pinworm
# Species:. Leucinodes ugandensis
# Common:
# Species:. Megalurothrips usitatus
# Common: Asian bean thrips
# Species:. Neoceratitis cyanescens
# Common: tomato fruit fly
# Species:. Scirtothrips dorsalis
# Common: nordindischer Teeblasenfuß
# Species:. Cassida bivittata
# Common: striped sweet potato beetle
# Species:. Chelymorpha cassidea
# Common: argus tortoise beetle
# Species:. Cylas femoralis
# Common: sweet-potato weevil
# Species:. Cylas formicarius
# Common: zweifarbiger Käfer
# Species:. Euscepes postfasciatus
# Common: sweet potato weevil
# Species:. Megastes grandalis
# Common: sweet potato moth borer
# Species:. Megastes pusialis
# Common: sweet potato moth borer
# Species:. Apogonia cribricollis
# Common:
# Species:. Cassida circumdata
# Common: green tortoise beetle
# Species:. Charidotella bicolor
# Common: golden tortoise beetle
# Species:. Deloyala guttata
# Common: mottled tortoise beetle
# Species:. Jonthonota nigripes
# Common: black-legged tortoise beetle
# Species:. Omphisa anastomosalis
# Common: sweet potato vine borer
# Species:. Bactrocera latifrons
# Common: solanum fruit fly
# Species:. Diaphania indica
# Common: cucumber moth
# Species:. Zeugodacus cucurbitae
# Common: tropische Melonenfliege
# Species:. Anastrepha grandis
# Common: South American fruit fly
# Species:. Apomecyna binubila
# Common: pumpkin stem borer
# Species:. Bactrocera dorsalis
# Common: orientalische Fruchtfliege
# Species:. Bactrocera zonata
# Common: peach fruit fly
# Species:. Ceratothripoides claratris
# Common: Oriental tomato thrips
# Species:. Dacus ciliatus
# Common: lesser pumpkin fly
# Species:. Epilachna elaterii
# Common: gefleckter Gurkenkäfer
# Species:. Myiopardalis pardalina
# Common: vorderasiatische Melonenfliege
# Species:. Acrolepiopsis assectella
# Common: porremøl
# Species:. Brachycerus albidentatus
# Common: onion weevil
# Species:. Caliothrips indicus
# Common: black thrips
# Species:. Delia antiqua
# Common: løgflue
# Species:. Delia hirticrura
# Common: onion fly
# Species:. Dyspessa ulula
# Common: Lauchbohrer
# Species:. Phytomyza gymnostoma
# Common: onion leaf miner
# Species:. Zeugodacus cucumis
# Common: cucumber fly
# Species:. Aulacophora abdominalis
# Common: orangenroter Melonenkäfer
# Species:. Bactrocera correcta
# Common: guava fruit fly
# Species:. Diaphania nitidalis
# Common: cucumber worm
# Species:. Bruchus pisorum
# Common: ærtefrøbille
# Species:. Bactrocera tryoni
# Common: Queenslandfruchtfliege
# Species:. Leucinodes africensis
# Common:
# Species:. Neoleucinodes elegantalis
# Common: small tomato borer
# Species:. Anastrepha suspensa
# Common: greater Antillean fruit fly
# Species:. Bactrocera carambolae
# Common: carambola fruit fly
# Species:. Bactrocera curvipennis
# Common: banana fruit fly
# Species:. Ceratitis cosyra
# Common: Natal-Fruchtfliege
# Species:. Ceratitis rosa
# Common: Natal fly
# Species:. Drosophila suzukii
# Common: Kirschessigfliege
# Species:. Leucinodes laisalis
# Common: Daraba idmonealis
# Species:. Zaprionus indianus
# Common: African fig fly
# Species:. Zonosemata electa
# Common: pepper maggot
# Species:. Anoplophora chinensis
# Common: Citrusbockkäfer
# Species:. Anarsia lineatella
# Common: ferskenmol
# Species:. Apriona cinerea
# Common: apple stem borer
# Species:. Carposina sasakii
# Common: peach fruit moth
# Species:. Choristoneura conflictana
# Common: aspen borer
# Species:. Chrysobothris femorata
# Common: flat-headed apple tree borer
# Species:. Eotetranychus lewisi
# Common: Lewis spider mite
# Species:. Euproctis chrysorrhoea
# Common: brunhale
# Species:. Grapholita funebrana
# Common: blommevikler
# Species:. Grapholita molesta
# Common: ferskenvikler
# Species:. Grapholita packardi
# Common: cherry fruit worm
# Species:. Grapholita prunivora
# Common: lesser apple worm
# Species:. Hyphantria cunea
# Common: hvid bjornespinder
# Species:. Lymantria dispar
# Common: lovskovnonne
# Species:. Malacosoma americanum
# Common: amerikanischer Ringelspinner
# Species:. Malacosoma disstria
# Common: forest tent caterpillar
# Species:. Malacosoma parallela
# Common: mountain ring silk moth
# Species:. Oligonychus perseae
# Common: persea mite
# Species:. Rhagoletis cingulata
# Common: white-banded cherry fruit fly
# Species:. Rhagoletis fausta
# Common: black cherry fruit fly
# Species:. Trirachys sartus
# Common: sart longhorn beetle
# Species:. Anastrepha fraterculus
# Common: südamerikanische Fruchtfliege
# Species:. Aromia bungii
# Common: Asiatischer Moschusbock
# Species:. Bactrocera pyrifoliae
# Common:
# Species:. Ceratitis quinaria
# Common: Rhodesien-Fruchtfliege
# Species:. Agrilus mali
# Common: apple buprestid
# Species:. Anastrepha ludens
# Common: mexikanische Fruchtfliege
# Species:. Capnodis tenebrionis
# Common: Pfirsichprachtkäfer
# Species:. Ceratitis fasciventris
# Common:
# Species:. Ceratitis malgassa
# Common: Madagassische Fruchtfliege
# Species:. Ceratitis quilicii
# Common:
# Species:. Chrysobothris mali
# Common: Pacific flat-headed borer
# Species:. Cydia pomonella
# Common: æblevikler
# Species:. Gymnandrosoma aurantianum
# Common: citrus fruit borer
# Species:. Oemona hirta
# Common: lemon tree borer
# Species:. Operophtera brumata
# Common: lille frostmåler
# Species:. Rhagoletis pomonella
# Common: æbleflue
# Species:. Rhagoletis suavis
# Common: walnut husk maggot
# Species:. Saperda candida
# Common: Rundköpfiger Apfelbaumbohrer
# Species:. Tetranychus fijiensis
# Common:
# Species:. Trichoferus campestris
# Common: mulberry longhorn beetle
# Species:. Acleris senescens
# Common: Teras senescens
# Species:. Anoplophora glabripennis
# Common: asiatischer Laubholzkäfer
# Species:. Apriona germari
# Common: longhorn stem borer
# Species:. Apriona rugicollis
# Common: mulberry borer
# Species:. Grapholita inopinata
# Common: Manchurian fruit moth
# Species:. Brevipalpus azores
# Common:
# Species:. Anastrepha obliqua
# Common: westindische Fruchtfliege
# Species:. Anastrepha serpentina
# Common: sapodilla fruit fly
# Species:. Anastrepha striata
# Common: guava fruit fly
# Species:. Anatrachyntis badia
# Common: Pyroderces badia
# Species:. Bactrocera caryeae
# Common: Dacus caryeae
# Species:. Bactrocera passiflorae
# Common: Fijian fruit fly
# Species:. Brevipalpus californicus
# Common: scharlachrote Teemilbe
# Species:. Brevipalpus lewisi
# Common: citrus flat mite
# Species:. Chaetanaphothrips signipennis
# Common: banana rust thrips
# Species:. Euzopherodes vapidella
# Common: Citrusstammmotte
# Species:. Luperomorpha xanthodera
# Common: rose flea beetle
# Species:. Massicus raddei
# Common: chestnut trunk borer
# Species:. Pezothrips kellyanus
# Common: Kelly's citrus thrips
# Species:. Phyllocnistis citrella
# Common: Citrusminiermotte
# Species:. Prays citri
# Common: Citrusmotte
# Species:. Prays endocarpa
# Common: citrus rind borer
# Species:. Selenothrips rubrocinctus
# Common: Kakaothrips
# Species:. Tiracola plagiata
# Common: banana fruit caterpillar
# Species:. Rhagoletis completa
# Common: amerikanische Walnußschalenfliege
# Species:. Thaumetopoea processionea
# Common: Eichenprozessionsspinner
# Species:. Acrobasis pirivorella
# Common: pear driller
# Species:. Adoxophyes orana
# Common: frugtskrælvikler
# Species:. Leucoptera malifoliella
# Common: cirkelminermol
# Species:. Eurytoma plotnikovi
# Common: braune Pistaziensamenwespe
# Species:. Brachycerus muricatus
# Common: garlic weevil
# Species:. Brachycerus undatus
# Common: garlic weevil
# Species:. Bactrocera oleae
# Common: Olivenfliege
# Species:. Prays oleae
# Common: Olivenmotte
# Species:. Aceria sheldoni
# Common: Citrusknospenmilbe
# Species:. Bactrocera minax
# Common: Chinese citrus fly
# Species:. Bactrocera tsuneonis
# Common: japanische Citrusfruchtfliege
# Species:. Brevipalpus papayensis
# Common:
# Species:. Brevipalpus phoenicis sensu stricto
# Common: Tenuipalpus phoenicis
# Species:. Brevipalpus tucuman
# Common:
# Species:. Ceratitis anonae
# Common: annona fruit fly
# Species:. Resseliella citrifrugis
# Common: citrus fruit midge
# Species:. Zaprionus tuberculatus
# Common:
# Species:. Scirtothrips perseae
# Common: avocado thrips
# Species:. Stenoma catenifer
# Common: avocado seed moth
# Species:. Bactrocera kandiensis
# Common: Bactrocera species D
# Species:. Neosilba glaberrima
# Common: Lonchaea glaberrima
# Species:. Neosilba zadolicha
# Common:
# Species:. Raoiella indica
# Common: red palm mite
# Species:. Rhagoletis mendax
# Common: blueberry maggot
# Species:. Halyomorpha halys
# Common: Marmorierte Baumwanze
# Species:. Laodelphax striatellus
# Common: Getreidezikade
# Species:. Listronotus bonariensis
# Common: wheat stem weevil
# Species:. Aeneolamia contigua
# Common: spotted spittlebug
# Species:. Asproparthenis punctiventris
# Common: Derbrüssler
# Species:. Bagrada hilaris
# Common: bagrada bug
# Species:. Brachyplatys subaeneus
# Common: black bean bug
# Species:. Cicadulina mbila
# Common: maize leafhopper
# Species:. Diaprepes abbreviatus
# Common: sugarcane root and stalk borer weevil
# Species:. Draeculacephala minerva
# Common: grass sharpshooter
# Species:. Haplaxius crudus
# Common: pallid cane leafhopper
# Species:. Homalodisca vitripennis
# Common: glassy-winged sharpshooter
# Species:. Naupactus leucoloma
# Common: white-fringed beetle
# Species:. Naupactus xanthographus
# Common: South American fruit tree weevil
# Species:. Perkinsiella saccharicida
# Common: Zuckerrohrzikade
# Species:. Reptalus panzeri
# Common:
# Species:. Anthonomus vestitus
# Common: Peruvian cotton square weevil
# Species:. Bemisia tabaci
# Common: Baumwollmottenschildlaus
# Species:. Conotrachelus denieri
# Common:
# Species:. Dysdercus cingulatus
# Common: red cotton bug
# Species:. Dysdercus fasciatus
# Common: cotton stainer
# Species:. Dysdercus peruvianus
# Common: Peruvian cotton stainer
# Species:. Eutinobothrus gossypii
# Common: gorgojo de la chupadera
# Species:. Gargaphia torresi
# Common: cotton lace bug
# Species:. Horcias nobilellus
# Common: gestreifte Baumwollwanze
# Species:. Jacobiasca lybica
# Common: afrikanische Baumwollzikade
# Species:. Oxycarenus hyalinipennis
# Common: kleine graue Baumwollwanze
# Species:. Oxycarenus lavaterae
# Common:
# Species:. Ricania speculum
# Common: Flatoides perforatus
# Species:. Dimorphopterus pilosus
# Common: Pacific rice chinch bug
# Species:. Nephotettix cincticeps
# Common: grüne japanische Reiszikade
# Species:. Nephotettix nigropictus
# Common: rice leafhopper
# Species:. Nephotettix parvus
# Common:
# Species:. Nephotettix virescens
# Common: Zwergzikade
# Species:. Nilaparvata lugens
# Common: Stirnhöckerzirpe
# Species:. Sogatella furcifera
# Common: Stirnhöckerzirpe
# Species:. Sogatodes orizicolus
# Common: amerikanische Reiszikade
# Species:. Leptocorisa acuta
# Common: gemeine Reiswanze
# Species:. Leptocorisa oratorius
# Common: braune Reiswanze
# Species:. Leptoglossus australis
# Common: Australian leaf-footed bug
# Species:. Scotinophara lurida
# Common: schwarze japanische Reiswanze
# Species:. Diuraphis noxia
# Common: russische Getreideblattlaus
# Species:. Phenacoccus solenopsis
# Common: solenopsis mealybug
# Species:. Maconellicoccus hirsutus
# Common: Hibiscusschmierlaus
# Species:. Pochazia shantungensis
# Common: Ricania shantungensis
# Species:. Bactericera cockerelli
# Common: amerikanischer Kartoffelblattsauger
# Species:. Nysius huttoni
# Common: wheat bug
# Species:. Eurygaster integriceps
# Common: asiatische Breitbauchwanze
# Species:. Cochlochila bullita
# Common: Ocimum tingid
# Species:. Lixus juncii
# Common: beet lixus
# Species:. Aleyrodes proletella
# Common: kålmellus
# Species:. Ceutorhynchus assimilis
# Common: kålgallesnudebille
# Species:. Ceutorhynchus sulcicollis
# Common: blåvinget rapssnudebille
# Species:. Eurydema oleraceum
# Common: kåltæge
# Species:. Eurydema ornata
# Common: gemeine Schmuckwanze
# Species:. Tyloderma brassicae
# Common: cabbage borer
# Species:. Acyrthosiphon kondoi
# Common: blue pea aphid
# Species:. Camptopus lateralis
# Common: camptope des genêts
# Species:. Hishimonus phycitis
# Common: Eutettix phycitis
# Species:. Hypera postica
# Common: lucernegnaver
# Species:. Circulifer tenellus
# Common: beet leafhopper
# Species:. Erthesina fullo
# Common: yellow spotted stink bug
# Species:. Pentastiridius leporinus
# Common: Schilf-Glasflügelzikade
# Species:. Premnotrypes latithorax
# Common: Andean potato weevil
# Species:. Premnotrypes sanfordi
# Common: Andean potato weevil
# Species:. Premnotrypes solani
# Common: Andean potato weevil
# Species:. Premnotrypes suturicallus
# Common: Andean potato weevil
# Species:. Premnotrypes vorax
# Common: Andean potato weevil
# Species:. Pseudococcus viburni
# Common: Affinis-Schmierlaus
# Species:. Russelliana solanicola
# Common: South American potato psyllid
# Species:. Anthonomus eugenii
# Common: Pfefferkäfer
# Species:. Aonidomytilus albus
# Common: cassava scale
# Species:. Clavigralla tomentosicollis
# Common: spiny brown bug
# Species:. Epicaerus cognatus
# Common: Mexican potato weevil
# Species:. Listroderes costirostris
# Common: sugarbeet webworm
# Species:. Listroderes difficilis
# Common: vegetable weevil
# Species:. Phenacoccus peruvianus
# Common: Bougainvillea mealybug
# Species:. Phyrdenus muriceus
# Common: barrenador del tallo del tomate
# Species:. Rhigopsidius tucumanus
# Common: tucuman weevil
# Species:. Trialeurodes ricini
# Common: castor bean whitefly
# Species:. Alcidodes dentipes
# Common: striped sweet potato weevil
# Species:. Alcidodes erroneus
# Common: sweet potato weevil
# Species:. Aleurothrixus trachoides
# Common: chilli whitefly
# Species:. Blosyrus ipomoeae
# Common: sweet potato leaf weevil
# Species:. Aleurodicus dispersus
# Common: spiralling whitefly
# Species:. Helopeltis schoutedeni
# Common: cotton helopeltis
# Species:. Planococcus kenyae
# Common: afrikanische Kaffeeschmierlaus
# Species:. Rhyssomatus landeiroi
# Common: sweet potato weevil
# Species:. Rhyssomatus sculpturatus
# Common: sweet potato weevil
# Species:. Aleurodicus dugesii
# Common: giant whitefly
# Species:. Aonidiella citrina
# Common: yellow scale
# Species:. Baris granulipennis
# Common: melon weevil
# Species:. Comstockaspis perniciosa
# Common: San José skjoldlus
# Species:. Bactericera tremblayi
# Common: Zwiebelblattsauger
# Species:. Neotoxoptera formosana
# Common: onion aphid
# Species:. Phlyctinus callosus
# Common: vine calandra
# Species:. Acanalonia conica
# Common: green cone-headed planthopper
# Species:. Margarodes vitis
# Common: ground pearls
# Species:. Myzus mumecola
# Common: Macrosiphum mumecola
# Species:. Parabemisia myricae
# Common: myrica whitefly
# Species:. Pseudococcus calceolariae
# Common: citrophilus mealybug
# Species:. Pseudococcus comstocki
# Common: Bananenschildlaus
# Species:. Scolytus schevyrewi
# Common: banded elm bark beetle
# Species:. Xyleborinus attenuatus
# Common: Xyleborinus alni
# Species:. Xylosandrus crassiusculus
# Common: Asian ambrosia beetle
# Species:. Aleurocanthus spiniferus
# Common: citrus mealywing
# Species:. Amblypelta cocophaga
# Common: coconut bug
# Species:. Conotrachelus nenuphar
# Common: nordamerikanischer Pflaumenrüssler
# Species:. Euwallacea fornicatus sensu lato
# Common: Teezweigbohrer
# Species:. Euwallacea fornicatus sensu stricto
# Common: polyphagous shot-hole borer
# Species:. Lycorma delicatula
# Common: Chinese blistering cicada
# Species:. Megaplatypus mutatus
# Common: taladrillo grande de los forestales
# Species:. Pseudaulacaspis pentagona
# Common: wit perske-dopluis
# Species:. Anthonomus pomorum
# Common: æblesnudebille
# Species:. Lepidosaphes ussuriensis
# Common: ussuri oystershell scale
# Species:. Aleurocanthus woglumi
# Common: schwarze Citrusmottenschildlaus
# Species:. Aphis illinoisensis
# Common: grapevine aphid
# Species:. Daktulosphaira vitifoliae
# Common: vindværglus
# Species:. Paraleyrodes minei
# Common: nesting whitefly
# Species:. Trioza erytreae
# Common: ostafrikanischer Zitrusblattfloh
# Species:. Aleurothrixus floccosus
# Common: flocculent whitefly
# Species:. Bathycoelia thalassina
# Common: African cocoa shield bug
# Species:. Ceroplastes ceriferus
# Common: indische Wachsschildlaus
# Species:. Ceroplastes destructor
# Common: wit wasdopluis
# Species:. Ceroplastes floridensis
# Common: Florida-Schildlaus
# Species:. Ceroplastes japonicus
# Common: tortoise wax scale
# Species:. Chrysomphalus aonidum
# Common: ronde persdopluis
# Species:. Coccus viridis
# Common: grüne Kaffeeschildlaus
# Species:. Dialeurodes citri
# Common: Zitrusmottenschildlaus
# Species:. Diaphorina citri
# Common: südostasiatischer Citrusblattfloh
# Species:. Distantiella theobroma
# Common: Sahlbergella theobroma
# Species:. Euwallacea perbrevis
# Common: Tea shothole borer
# Species:. Gascardia brevicauda
# Common: white waxy scale
# Species:. Hishimonus diffractus
# Common:
# Species:. Icerya aegyptiaca
# Common: Egyptian fluted scale
# Species:. Icerya purchasi
# Common: australiese luis
# Species:. Icerya seychellarum
# Common: yellow cottony cushion scale
# Species:. Lopholeucaspis japonica
# Common: Japanese long scale
# Species:. Neoaliturus haematoceps
# Common: Circulifer haematoceps
# Species:. Orchamoplatus citri
# Common: Australian citrus whitefly
# Species:. Pachnaeus azurescens
# Common: citrus weevil
# Species:. Parasaissetia nigra
# Common: schwarze Napfschildlaus
# Species:. Parlatoria ziziphi
# Common: pikswart dopluis
# Species:. Planococcus lilacinus
# Common: asiatische Kaffeeschmierlaus
# Species:. Unaspis citri
# Common: schneeweiße Citrusschildlaus
# Species:. Unaspis yanonensis
# Common: arrowhead scale
# Species:. Cnestus mutilatus
# Common: camphor shot borer
# Species:. Xyleborus ferrugineus
# Common: black twig borer
# Species:. Euwallacea kuroshio
# Common: Kuroshio shothole borer
# Species:. Pityophthorus juglandis
# Common: walnut twig beetle
# Species:. Anthonomus piri
# Common: Birnenknospenstecher
# Species:. Cacopsylla pyri
# Common: brunplettet pærebladloppe
# Species:. Anthonomus quadrigibbus
# Common: amerikanischer Apfelrüssler
# Species:. Aphis citricidus
# Common: braune Citrusblattlaus
# Species:. Cacopsylla chinensis
# Common: Psylla chinensis
# Species:. Corythucha arcuata
# Common: oak lace bug
# Species:. Trioza apicalis
# Common: gulerodsbladloppe
# Species:. Orientus ishidae
# Common: Japanese leafhopper
# Species:. Xylosandrus compactus
# Common: schwarzer Kaffeezweigbohrer
# Species:. Orchamoplatus mammaeferus
# Common: croton whitefly
# Species:. Aleurocanthus citriperdus
# Common: Aleurocanthus cameroni
# Species:. Penthimiola bella
# Common: citrus leafhopper
# Species:. Amblypelta lutescens
# Common: banana spotting bug
# Species:. Conotrachelus aguacatae
# Common: avocado weevil
# Species:. Conotrachelus perseae
# Common: avocado weevil
# Species:. Heilipus lauri
# Common: Avocadorüssler
# Species:. Pseudacysta perseae
# Common: avocado lace bug
# Species:. Tetraleurodes perseae
# Common: red-banded whitefly
# Species:. Xylosandrus morigerus
# Common: brauner Kaffeezweigbohrer
# Species:. Ceroplastes stellifer
# Common: Sternschildlaus
# Species:. Euplatypus parallelus
# Common: Platypus parallelus
# Species:. Helopeltis antonii
# Common: schwarze Teewanze
# Species:. Xyleborus glabratus
# Common: redbay ambrosia beetle
# Species:. Xyleborus neivai
# Common:
# Species:. Xyleborus perforans
# Common: sugarcane ambrosia beetle
# Species:. Aonidiella orientalis
# Common: oriental scale
# Species:. Ripersiella hibisci
# Common: root mealybug
# Species:. Anthonomus bisignifer
# Common: Japanese strawberry blossom weevil
# Species:. Anthonomus signatus
# Common: strawberry clipper
# Species:. Stephanitis takeyai
# Common: takeya lace bug
# CPU times: user 38.8 s, sys: 708 ms, total: 39.5 s
# Wall time: 2min 51s
#   pest_eppocode         scientific_name                 common_name
# 0        APLOBE  Aphelenchoides besseyi          white-tip nematode
# 0        HETDZE         Heterodera zeae          corn cyst nematode
# 0        PUNCCH  Punctodera chalcoensis  Mexican corn cyst nematode
# 0        DITYDE  Ditylenchus destructor         kartoffelradnematod
# 0        DITYDI     Ditylenchus dipsaci              stængelnematod

# %%
# save to csv
df_common.to_csv('../process_data/pest_common.csv')
